# %%
 
#print("hello world this is umar"," abbas ",sep=" ? ",end=" ")

#print("hello world")

#sepration means the sepration between different strings inside the same print statements 

#end mean when we end the string what operarion we want to perform /n mean next line or anything of our choice

#python is completely oop base and it all made in classes and functions

#variables 

#varible are storage locations to store different data

#we donot define data types in python identify by itself

#rules for variable are same as c++ and js

#x=5
#y=5.5

#print(x+y)

#to check type of variable

#print(type(x))

#print(type(y))

#data types

#integer string boolean float and none ( none mean nothing value is assigned )

#string can be single double or triple quotes 

#a = None

#print(type(a))

#a #this simple will throw error intializing it compulsory 

#python is also case sensitive 

#punctuators are symbols to organize sentence structure in programming

#eg () {} # += -+ etc

#python is implicit typed language because we not need to provide the type of varibale 

#c++ is explicitly typed language becuase we have to tell the varibale type

# strings with + is used to concatenate

# strings with  * is used to multiple taht string n times


# name =" umar"
# name1="abbas"

#print((name+name1)*3,)

# result of integer and float result in float 

# when we use division operator and result is also float  this opertor  /

#when we use it convert float to lowest nearest integer and dispaly ass float  this operator //

#same result as floor  a//b =floor(a/b)


a= 5

b=3



#print(a/b)

#print(a//b)


#reminder is negative when denominator is neagtive and numenator is postive other wise positive in all cases %

#+%+ +

#+%- -

#-%- +

#-%+ =


# colour = "red"

#if(colour == "red" ):
#   print("red")
#else:
#   print("not")

#single line condition or you can say ternary conditions

#p = "yes" if colour=="red" else "no"

#print(p)


#clever if 


#a =(5,10) [colour=="red"]  # in square bracket we are checking the condition and we not normally use it 


#print(a)


#print(input("name"))   work and print output directly wheich enter and also provide history of all inputs 


#input(print("name"))  gives error  deadlock which mean it search for input but have print function



#a= float(input("digit"))

#b= int(float(input("digit")))

#print(a)

#print(b)

#input always return the string and we have to type cast it to integer and float 

#we cannot directly convert string input of float to integer so we have to change it to integer then change it to integer for use


# operators in python

# 1 airthmetic operators

# 2 logical operators and not or 

# 3 assignment operator =

# 4 relational operator == >= <=


# type cconversion and type casting

# conversion automatically and casting manually

# convertion example sum of of int and float automatically return float



# we cannot add float to string

# but when we add int to string it concate it with string

#strings 

#strings can be store in single double and triple quoute

# why there is need of single double and triple string lets say we have to use single or double quote in strings so we can use that

# z = 'my name is "umar" '

# z = "my name is 'umar' "

# z = "'my name is "umar" '"
# print(z)

# bio = """My name is Umar.
# I am learning Python.
# I can write multi-line text easily."""
# print(bio)


# name = input("name")


# print("my name is "+'"'+name+'"')

# print(f"my name is {)

# print('my name is ',name,'',sep='"') 


# f satnds for formatted string it is used to add varibales in the string and use f before the string to use this 

#r stands for raw strings and its used to not treat \ as special character eg

# \n (new line)

# \t (tab)

# \r (carriage return)   bring cursor to start by repalcing the world

# \\ (escaped backslash)


# print("hello\nworld")  print two words in next line

# print(r"hello\nworld")  #print two words in same line

# if we want to write two three sentences in single varible we use triple quotes

# print(r"hello\rworld")


#use of carriage return

# import time

# for i in range(0,10):
#     print(f"loading {i}",end="\r")
#     time.sleep(0.5)
# print()
# print("done")

# concatenation mean two combine two strings by using +


# name="umar"

# len("umar")

# len(name)  both are valid 

#in strings both nnegative and positive indexing exist positive form start and neagtive form end

# strings and tuple are immutable in string

# list and dictionary are mutbale


# name="umar"



# print(name[-4])

# slicing  create new string not modify existing 


# str[start:end:steps]

str="my name is umar"

# print(str[0:])   #print complete string from start to end (length)

# print(str[0:1])  #print form zero to zero 

#it include the starting index and exclude the ending index

# print(str[0::2])  #strart from zero to end by picking every second

# print(str[:5]) #from start to 4

#if we add wrong index it print nothing

#negative slicing


# print(len(str))

# print(str[-15:-1])   #its not print last

# print(str[-15:0])   #its print nothing

# print(str[-15:]) 
 
# str = 'my name is "umar"'   #in this case the quotes also consider as indexes

# print(len(str))

# print(str[-17:-1:])


# string functions 

# function not change the original string and return new 


# endswith return true or false and decide weather string end with specfic charcter or not

# captalize mean it captalize first charchter of that string  not change in original string

# to upper and lower used to convert to upper and lower case not change in original string

# find retur the first occurance of that charcter in the string  -1 if not found

# index also return the index but if not found return error

# count counts the number of occurance of substring in the string

#replace also not change the original string but create a new string

# s.title capital the first letter of each word


# strip all three return new string and not chanege in the existing string 

# strip remove spaces from left and right

# lstrip remove spaces from left

# rstrip remove spaces form right

# index return the index of string else error


# split used to split in the bases of spaces or commas or anything 

# print(str.strip())
# print(str.lstrip())
# print(str)
# print(str.rstrip())


# print(str.title())   




# print(str.capitalize())

# print(str.lower())
# print(str.upper())

# print(str)




# print(str.find("u"))


# print(str.count("ar"))


# print(str.replace("umar","ali"))

# print(str)


# print(str.endswith("ar"))

# print(str.startswith("ar"))

# print(str.find("az"))

# print(str.index("ar"))

# print(str.index("az"))


# print(str.split(""))   #empty separtor nit allowed

# print(str.split(" "))


# all below check weather all charcters are letters or alphberts or spaces and return true false on that bases


# print(str.isdigit())

# print(str.isalpha())

# print(str.isalnum())

# print(str.isspace())


# conditional statement


# if elif and else is used 

# we use tab or four spaces and we call it intendation without it throw error


# age=18


# if(age>18):
#     print("you are eligible")
# elif(age<18 and age>1):
#     print("you are not eligble")
# else:
#     print("invalid age")



# list


# lists are just like arrays in other languages

# lists are same like strings in python

# lists are mutbale 

# we can save mix type of data in lists like integer sting and float in same list

#also suppport negative indexing just like arrays



# slicing is same like strings in lists


list = [1,2,4,5]


# print(list[0:])   #print complete


# print(list[:len(list)])   #print complete


# print(list[0::2])   #print with evey two characters

# print(list[-5:])   #print complete


# print(list[-5::2])   #print complete  eveye two


# print(len(list))

# print(type(list))


# listmethods


#methods are specfic to every structure


# append method is same like push method in js it is used to add element at the end  it change in the given list

# pop is use to remove last element from the list  it also change in the given list

# exten is used to add list or iterables at the end 

# insert is used to insert at specfic index inser(index,elemet)

# remove is used to rmeove the specfic element in list repeaated many time remove all elements if not exit it do nothinh return nothing

# clear is used to remove all the element and clear the list

# count return how many time specfic elelment exist

# sort is used to sort the list only work if all integers or all string not combine  and sort in given place sorting also apply on alphatbets based on ascii values 

# most of method return none whcih is data type in python mean absecnce of anything



# list.append(1)

# list.append(2)

# list.pop()     remove the specific index of that element

# list.extend([10,12])

# list.insert(0,0)

# list.remove(0)    remove the first occurance of that element

# print(list.count(1))

# list.reverse()    in original string not new string 

# list.sort(reverse=True)   #to print in descneding

# list.sort()     #in ascending

# l=list.copy()

# print(l)

# print(list)



# tuples

#work same as list but tuple are immutable just like strings 

#it also allow negative indexing 

# tuple=(1,2,3,3,(7,8,9))     #nested tuple

# print(tuple[4][0])

# print(type(tuple))

# print(tuple[0])

# tuple[0]=10   #give error becuase they are immutable


# tup=()   #empty tuple 


# tuple1=(1,)   to create single value tuple we create it with comma otherwise it will take it as integer string or float

#it work without comma but it consider it not as tuple 

# print(tuple1)

# print(type(tuple1))


# slicing is same as list and string 

# print(tuple[0:])

# print(tuple[:len(tuple)])

# print(tuple[0::2])

# print(tuple[-4:])


# methods in tuple

# print(tuple.index(1))    if element exist it return it otherwisw it thorw error

# print(tuple.count(1))   return the count of element in the tuple 



# Dictionaries and sets 


# dictionaries are used to store data in the form of key value pair

# they are unorder mutable and not allow duplicate keys

# key can be int boolean tuple float or string but noramlly we use string


# dict ={

#     "name":"umar",
#     "age":10,
#     "marks":100,
#     "amount":[1,2,3],
#     "tup":(1,2,3),
#     "score":{               #nesting dictionaries
#         "math":10,
#         "eng":20,
#         "sci":30
#     }

# }

# dict["subject"]="Englis"   #to assign new value

# dict["name"]="ali"     #to assign new value

# print(type(dict))

# print(dict)



# print(dict["amount"][0])

# print(dict["tup"])


# dict1={}  #to create null and then can add values

# print(dict1)


#methods


# print(dict.keys())      #return all the keys    list(dict(keys))  type cast to keys

# print(dict.values())      #return all the values 

# print(dict.items())      #return all the keys value pair as tuple

# print(dict.get("name"))      #return all the value according to key if not exit return nonoe

# print(dict.update({"a":"b"}))     #pass new dict orr key values can have mutiple seprated with commma

# print(dict)


# sets 

# collection of unorder items

# all values are unique and sets are immutbale 

#we cannot store list or dictionaries in sets becuase they are mutable and we can store tuple and strings and other unique value that cannot change in stes


set = {1,2,3,4}     #if there is any duplicate value then ste igonre it and there is no eroror


# print(set)

# print(type(set))

# print(len(set))    #also ignore duplicate


#to create empty


# empty = set()     #to create empty but this is throwing error right now

# print(type(empty))


#methods


# set.add(10)    #to add something

# set.add("umar")

# set.add([1,3,3])   # thorw error becuse list are mutable

# # set.add({1,3,3})   # thorw error becuse dictionaries are mutable

# set.add((1,3,3))   # can pass becuse tuple are mutable



# set.remove(12)    #if not exit it throw error otherwisw remove it 

# set.clear()  to clear


# set.pop()  #  to remove randome value 

# print(set)



# sets are mutable mean we can add or reomve but set element all immutable that we cannot change  


# in add we can pass string or tuple but cannot list or dict


#unhasable values mean the value that can be change and it thorw error when we add some list in set 

# set1={10,111,12}


#both union and intersection return new set and no change in original set


# print(set.union(set1))     return the union of two sets

# print(set.intersection(set1))   return intersectionof two sets 



#to store 9 and 9.0 in set

# set1={("int",9),("float",9.0)}    

# #one solution make one value string

# #second solution make tuple pairs in sets 

# #python consider 9 and 9,0 same

# print(set1)    #print 9 only and consider 9.0 as duplicate
# Out:
# {('int', 9), ('float', 9.0)}
